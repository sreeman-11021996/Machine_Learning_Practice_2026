# %%
def error_log(logger_msg:str=""):
    if logger_msg:
        print(logger_msg)
    else:
        print("Error msg")

# %%
error_log(logger_msg="my error msg")
# Out:
# my error msg

# %%
error_log()
# Out:
# Error msg
