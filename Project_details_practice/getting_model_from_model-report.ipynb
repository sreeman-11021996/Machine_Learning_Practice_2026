# %%
model_report : dict = {'linear' : 0.8, 'ridge' : 0.7, 'dtree' : 0.9}

# %%
# best_model_score 
best_model_score = max(model_report.values())
print (f"best model socre : {best_model_score}")
# Out:
# best model socre : 0.9

# %%
model_report

# %%
# best model name
best_model_name = list(model_report.keys())[list(model_report.values()).index(best_model_score)]
print(f"best model name : {best_model_name}")
# Out:
# best model name : dtree

# %%
#v model_report.items(), key=lambda x: x[1]

max(model_report.items(), key = lambda x: x[1])
# Out:
# ('dtree', 0.9)

# %%
model_report = {'linear': 0.9, 'ridge': 0.7, 'dtree': 0.9}

# Get ALL models with maximum score
max_score = max(model_report.values())
best_models = [name for name, score in model_report.items() if score == max_score]

print(f"Best score: {max_score}")
print(f"Top models: {best_models}")
# Out:
# Best score: 0.9
# Top models: ['linear', 'dtree']

# %%
model_report = {'models' : {'linear': 'linear_model', 'ridge': 'ridge_model', 'dtree': 'dtree_model'},
                'r2score' : {'linear': 0.9, 'ridge': 0.7, 'dtree': 0.9}, 
                'overfitting' : {'linear': 0.02, 'ridge': 0.01, 'dtree': 0.05}}

# %%
max_score = max(model_report['r2score'].values())
best_models = [name for name,score in model_report['r2score'].items() if score == max_score]

print(f"Best r2score: {max_score}")
print(f"Top models: {best_models}")
# Out:
# Best r2score: 0.9
# Top models: ['linear', 'dtree']
