# %%
import logging
import os
from datetime import datetime

# %%
logging.debug("debug")
logging.info("info")

# below will log into consol
logging.warning("warning")
logging.error("error")
logging.critical("critical")
# Out:
# WARNING:root:warning
# ERROR:root:error
# CRITICAL:root:critical

# %%
# Logging Level : logger used : log message

# %%
from datetime import datetime

# %%
# log file name
log_file = f"{datetime.now().strftime('%m_%d_%Y_%H_%M_%S')}"
print(log_file)
# Out:
# 03_01_2026_12_34_34

# %%
# Explained :
# datetime.mow() == Returns the current date and time from your system clock
print(datetime.now())
# Out:
# 2026-03-01 12:36:43.269925

# %%
# strftime('%m_%d_%Y_%H_%M_%S') == Converts a datetime object into a formatted string
